# %% [markdown]
# <h1> Test Yourselves </h1>

# %% [markdown]
# <h2> Import Libraries </h2>
# <p> Start by importing all the libraries to check if they have been imported successfully.</p>

# %%
import warnings, osmnx
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd
import scipy
import sklearn
import matplotlib.pyplot as plt
import seaborn as sns
import shapely
import geopandas as gpd
import fiona
import xarray as xr
import rioxarray
import osmnx as ox
import datashader
import contextily as cx
import pysal

print("All required libraries were imported successfully.")
# Out:
# All required libraries were imported successfully.

# %% [markdown]
# <h2> Your Task: </h2>
# <p>
#     Write a function that multiplies two values and prints the result.
# </p>

# %%
#Write function here
